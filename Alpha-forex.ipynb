# %%
from alpha_vantage.foreignexchange import ForeignExchange
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint

key_path = "E:\\Harish\\nsepywork\\docs\\alpha.txt"
ts = TimeSeries(key='RDPF5X348FY9NYHO', output_format='pandas')
fx = ForeignExchange(key='RDPF5X348FY9NYHO', output_format='pandas')

""" cc = ForeignExchange(key='RDPF5X348FY9NYHO')
# There is no metadata in this call
data, _ = cc.get_currency_exchange_rate(from_currency='BTC',to_currency='USD')
pprint(data) """

data,metadata = ts.get_intraday(symbol = "USDINR",interval= "1min" , outputsize = "full")
print(data)
# Out:
# 1. open  2. high  3. low  4. close  5. volume
# date
# 2020-08-14 16:38:00   74.853   74.853  74.853    74.853        0.0
# 2020-08-14 16:37:00   74.853   74.853  74.853    74.853        0.0
# 2020-08-14 16:36:00   74.853   74.853  74.853    74.853        0.0
# 2020-08-14 16:35:00   74.853   74.853  74.853    74.853        0.0
# 2020-08-14 16:34:00   74.853   74.853  74.853    74.853        0.0
# ...                      ...      ...     ...       ...        ...
# 2020-08-13 22:50:00   74.806   74.806  74.806    74.806        0.0
# 2020-08-13 22:49:00   74.806   74.806  74.806    74.806        0.0
# 2020-08-13 22:48:00   74.806   74.806  74.806    74.806        0.0
# 2020-08-13 22:47:00   74.806   74.806  74.806    74.806        0.0
# 2020-08-13 22:46:00   74.806   74.806  74.806    74.806        0.0
#
# [1073 rows x 5 columns]
